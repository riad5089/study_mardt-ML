# %%
df=pd.read_csv(r"C:\Users\Abdur rahim nishad\Downloads\agora.csv")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df.Transport=df.Transport.fillna(df.Transport.median())

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
 df.Area=le.fit_transform(df["Area"])

# %%
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    df[column]=le.fit_transform(df[column])
# Out:
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_2212/1696928730.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#     Marketing Spend  Administration  Transport  Area
# 0         114523.61       136897.80  471784.10     1
# 1         162597.70       151377.59  443898.53     0
# 2         153441.51       101145.55  407934.54     2
# 3         144372.41       118671.85  383199.62     1
# 4         142107.34        91391.77  366168.42     2
# 5         131876.90        99814.71  362861.36     1
# 6         134615.46       147198.87  127716.82     0
# 7         130298.13       145530.06  323876.68     2
# 8         120542.52       148718.95  311613.29     1
# 9         123334.88       108679.17  304981.62     0
# 10        101913.08       110594.11  229160.95     2
# 11        100671.96        91790.61  249744.55     0
# 12         93863.75       127320.38  249839.44     2
# 13         91992.39       135495.07  252664.93     0
# 14        119943.24       156547.42  256512.92     2
# 15        165349.20       122616.84  261776.23     1
# 16         78013.11       121597.55  264346.06     0
# ...

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,ytrain,xtest,ytrain=train_test_split(x,y,test_size=.3,random_state=50)

# %% [markdown]
# # Min max scaler/Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm=MinMaxScaler()

# %%
scale_xtrain=mm.fit_transform(xtrain)

# %%
scale_xtrain
# Out:
# array([[0.87313643, 0.51299839, 0.81223513, 0.5       ],
#        [0.23319442, 0.24130912, 0.3709309 , 0.        ],
#        [1.        , 0.54302973, 0.55486446, 0.5       ],
#        [0.16869099, 0.25446874, 0.34861436, 1.        ],
#        [0.52264964, 0.77823604, 0.45494286, 0.5       ],
#        [0.        , 0.50014806, 0.09574943, 0.        ],
#        [0.69261666, 0.65174393, 1.        , 0.5       ],
#        [0.74590551, 0.43692884, 0.64644319, 0.        ],
#        [0.61635061, 0.45150637, 0.48573267, 1.        ],
#        [0.47408436, 0.78021012, 0.63532724, 0.5       ],
#        [0.57246821, 0.71401273, 0.59894835, 0.5       ],
#        [0.        , 0.64054682, 0.        , 0.        ],
#        [0.46116861, 0.47642362, 0.63305328, 0.        ],
#        [0.17390063, 0.51204073, 0.36626005, 0.        ],
#        [0.13412668, 0.78807166, 0.06005866, 0.        ],
#        [0.45557444, 0.70684477, 0.28413435, 1.        ],
# ...

# %%
#scale_xtest=mm.transform(xtest)

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()

# %%
x=mm.fit_transform(x)

# %%
x
# Out:
# array([[0.69261666, 0.65174393, 1.        , 0.5       ],
#        [0.98335946, 0.76197173, 0.94089337, 0.        ],
#        [0.92798459, 0.37957895, 0.8646636 , 1.        ],
#        [0.87313643, 0.51299839, 0.81223513, 0.5       ],
#        [0.85943772, 0.30532804, 0.77613557, 1.        ],
#        [0.797566  , 0.3694479 , 0.76912588, 0.5       ],
#        [0.81412828, 0.73016111, 0.27071031, 0.        ],
#        [0.7880179 , 0.71745725, 0.68649342, 1.        ],
#        [0.72901786, 0.74173276, 0.66049977, 0.5       ],
#        [0.74590551, 0.43692884, 0.64644319, 0.        ],
#        [0.61635061, 0.45150637, 0.48573267, 1.        ],
#        [0.60884455, 0.30836422, 0.52936195, 0.        ],
#        [0.56766982, 0.57883556, 0.52956308, 1.        ],
#        [0.55635219, 0.64106561, 0.53555202, 0.        ],
#        [0.72539353, 0.8013272 , 0.54370828, 1.        ],
#        [1.        , 0.54302973, 0.55486446, 0.5       ],
# ...

# %%
df_x=pd.DataFrame(x,columns=["Marketing Spend","Administration","Transport","Area"])

# %%
df_x
# Out:
#     Marketing Spend  Administration  Transport  Area
# 0          0.692617        0.651744   1.000000   0.5
# 1          0.983359        0.761972   0.940893   0.0
# 2          0.927985        0.379579   0.864664   1.0
# 3          0.873136        0.512998   0.812235   0.5
# 4          0.859438        0.305328   0.776136   1.0
# 5          0.797566        0.369448   0.769126   0.5
# 6          0.814128        0.730161   0.270710   0.0
# 7          0.788018        0.717457   0.686493   1.0
# 8          0.729018        0.741733   0.660500   0.5
# 9          0.745906        0.436929   0.646443   0.0
# 10         0.616351        0.451506   0.485733   1.0
# 11         0.608845        0.308364   0.529362   0.0
# 12         0.567670        0.578836   0.529563   1.0
# 13         0.556352        0.641066   0.535552   0.0
# 14         0.725394        0.801327   0.543708   1.0
# 15         1.000000        0.543030   0.554864   0.5
# 16         0.471808        0.535270   0.560312   0.0
# ...

# %% [markdown]
# # standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
x=std.fit_transform(x)

# %%
x
# Out:
# array([[ 0.89791312,  0.56075291,  2.1873888 ,  0.02462576],
#        [ 1.95586034,  1.08280658,  1.94955411, -1.20666232],
#        [ 1.75436374, -0.72825703,  1.64281897,  1.25591385],
#        [ 1.55478369, -0.09636463,  1.43185602,  0.02462576],
#        [ 1.5049372 , -1.07991935,  1.28659774,  1.25591385],
#        [ 1.27980001, -0.77623907,  1.25839198,  0.02462576],
#        [ 1.34006641,  0.93214721, -0.7471445 , -1.20666232],
#        [ 1.24505666,  0.87198001,  0.92589352,  1.25591385],
#        [ 1.03036886,  0.9869521 ,  0.82129966,  0.02462576],
#        [ 1.09181921, -0.45664025,  0.76473846, -1.20666232],
#        [ 0.62039825, -0.38759909,  0.11806761,  1.25591385],
#        [ 0.59308542, -1.0655396 ,  0.29362415, -1.20666232],
#        [ 0.44325987,  0.21544906,  0.29443346,  1.25591385],
#        [ 0.4020776 ,  0.51017895,  0.31853193, -1.20666232],
#        [ 1.01718075,  1.26919939,  0.35135125,  1.25591385],
# ...

# %% [markdown]
# # RobustScaler

# %%
from sklearn.preprocessing import RobustScaler
rob=RobustScaler()

# %% [markdown]
# # MaxAbsScaler

# %%
from sklearn.preprocessing import MaxAbsScaler

rob=MaxAbsScaler()

# %% [markdown]
# # Power TRansformation

# %%
from sklearn.preprocessing import PowerTransformer

# %%
scale=PowerTransformer(method="yeo-johnson")

# %% [markdown]
# # manual

# %%
df["Marketing Spend"].max()
# Out:
# 165349.2

# %%
df["Marketing Spend"]=df["Marketing Spend"]/df["Marketing Spend"].max()

# %%
df["Marketing Spend"]
# Out:
# 0     0.692617
# 1     0.983359
# 2     0.927985
# 3     0.873136
# 4     0.859438
# 5     0.797566
# 6     0.814128
# 7     0.788018
# 8     0.729018
# 9     0.745906
# 10    0.616351
# 11    0.608845
# 12    0.567670
# 13    0.556352
# 14    0.725394
# 15    1.000000
# 16    0.471808
# 17    0.572468
# 18    0.554881
# 19    0.522650
# 20    0.461169
# 21    0.474084
# 22    0.447505
# 23    0.408424
# 24    0.465947
# 25    0.391080
# 26    0.455574
# 27    0.436093
# 28    0.399467
# 29    0.396769
# 30    0.374931
# 31    0.369741
# 32    0.383485
# 33    0.335617
# 34    0.280776
# 35    0.278284
# 36    0.173353
# 37    0.266527
# 38    0.122345
# 39    0.233194
# 40    0.173901
# 41    0.168691
# 42    0.142976
# 43    0.093776
# 44    0.134127
# 45    0.006049
# 46    0.007956
# 47    0.000000
# 48    0.003278
# 49    0.000000
# Name: Marketing Spend, dtype: float64
