# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Abdur rahim nishad\Downloads\tree.csv")

# %%
df.head()
# Out:
#    Days Outlook Temprature  Routine Wear Jacket?
# 0     1   Sunny       Cold  Indoor            No
# 1     2  Cloudy       Cold  Indoor           Yes
# 2     3  Cloudy       Warm  Outdoor           No
# 3     4   Sunny       Cold  Outdoor          Yes
# 4     5  Cloudy       Cold  Outdoor          Yes

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
# for column in df.columns:
#     if df[column].dtype==np.int64:
    
#         continue
#     if df[column].dtype==np.bool_:
    
#         continue
#     df[column]=LE.fit_transform(df[column])

# %%
df.head()
# Out:
#    Days Outlook Temprature  Routine Wear Jacket?
# 0     1   Sunny       Cold  Indoor            No
# 1     2  Cloudy       Cold  Indoor           Yes
# 2     3  Cloudy       Warm  Outdoor           No
# 3     4   Sunny       Cold  Outdoor          Yes
# 4     5  Cloudy       Cold  Outdoor          Yes

# %%
df.Outlook=LE.fit_transform(df.Outlook)
df.Temprature=LE.fit_transform(df.Temprature)
df.Routine=LE.fit_transform(df.Routine)

# %%
df.head()
# Out:
#    Days  Outlook  Temprature  Routine Wear Jacket?
# 0     1        1           0        0           No
# 1     2        0           0        0          Yes
# 2     3        0           1        1           No
# 3     4        1           0        1          Yes
# 4     5        0           0        1          Yes

# %%
x=df.iloc[:,1:4].values

# %%
# x.head()

# %%
y=df.iloc[:,-1].values

# %%
# y.head()

# %% [markdown]
# # Decision TRee

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(clf)
# Out:
# [Text(669.5999999999999, 951.3000000000001, 'X[1] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(446.4, 679.5, 'X[0] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(223.2, 407.70000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(669.5999999999999, 407.70000000000005, 'X[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(446.4, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(892.8, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(892.8, 679.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]')]

# %%
clf.predict([[1,0,1]])
# Out:
# array(['Yes'], dtype=object)
